# %%
# %matplotlib inline
import os
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
from torch.utils.data import DataLoader
from torch.cuda.amp import autocast, GradScaler
from ast import literal_eval
from sklearn.metrics import confusion_matrix

# Import your custom modules
# Ensure dataset.py, model.py, etc. are in the same folder
from src.dataset import AirbusDataset
from src.transforms import get_transforms
from src.model import ShipSegmenter
from src.losses import TverskyLoss, BCEDiceLoss # Or ComboLoss if you named it that

# --- CONFIGURATION ---
CONFIG = {
    "TRAIN_CSV": "./data/train_split.csv",
    "VAL_CSV": "./data/val_split.csv",
    "IMG_DIR": "./data/train_v2/",
    "IMG_SIZE": 768,
    "BACKBONE": "efficientnet-b4",
    "BATCH_SIZE": 8,          
    "LR": 1e-4,               
    "EPOCHS": 15,             
    "NUM_WORKERS": 4,         
    "DEVICE": "cuda" if torch.cuda.is_available() else "cpu",
    "THRESHOLD": 0.5 # Default starting threshold
}

print(f"Running on device: {CONFIG['DEVICE']}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 17
#      13 from sklearn.metrics import confusion_matrix
#      15 # Import your custom modules
#      16 # Ensure dataset.py, model.py, etc. are in the same folder
# ---> 17 from src.dataset import AirbusDataset
#      18 from src.transforms import get_transforms
#      19 from src.model import ShipSegmenter
#
# ModuleNotFoundError: No module named 'src'

# %%
import os
import sys

# Create the src directory one level up if it doesn't exist
os.makedirs('../src', exist_ok=True)

# Add the 'src' directory to Python's search path
sys.path.append(os.path.abspath('../src'))

# Now Python can see files inside 'src'
print("Search path updated. You can now import from ../src/")
# Out:
# Search path updated. You can now import from ../src/
